# %%
import numpy as np

# %%
arr = np.array([1,2,3,4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
arr.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Cambio tipo de datos

# %%
arr = np.array([1,2,3,4], dtype='float64')
print(arr)
print(arr.dtype)
# Out:
# [1. 2. 3. 4.]
# float64

# %%
arr = np.array([1,2,3,4])
arr = arr.astype(np.float64)
print(arr)
print(arr.dtype)
# Out:
# [1. 2. 3. 4.]
# float64

# %%
arr = np.array([0, 1,2,3,4])
arr = arr.astype(np.bool_)
print(arr)
print(arr.dtype)
# en boolean el 0 siempre es falso, mientras que el resto verdadero
# Out:
# [False  True  True  True  True]
# bool

# %%
arr = np.array([0, 1,2,3,4])
arr = arr.astype(np.string_)
print(arr)
print(arr.dtype)
# En string los maneja como cadenas de caracteres
# Out:
# [b'0' b'1' b'2' b'3' b'4']
# |S21

# %%
arr = np.array(['0', '1','2','3','4'])
arr = arr.astype(np.int8)
print(arr)
print(arr.dtype)
# Es capaz de coger los numeros que son string a int
# pero falla si intenta convertir caracteres a numeros
# Out:
# [0 1 2 3 4]
# int8

# %% [markdown]
# El array de numpy debe tener todos los elementos del mismo tipo, si no fallará
