# %%
import numpy as np

# %%
arr = np.random.randint(2,20,(3,2))

# %%
arr
# Out:
# array([[13, 18],
#        [18,  2],
#        [14, 11]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.reshape(1,6)
# Out:
# array([[13, 18, 18,  2, 14, 11]])

# %%
arr.reshape(2,3)
# Out:
# array([[13, 18, 18],
#        [ 2, 14, 11]])

# %%
np.reshape(arr, (1,6))
# Out:
# array([[13, 18, 18,  2, 14, 11]])

# %%
arr
# Out:
# array([[13, 18],
#        [18,  2],
#        [14, 11]])

# %%
np.reshape(arr, (2,3), 'C') # Como lo hace C, tomando por filas
# Out:
# array([[13, 18, 18],
#        [ 2, 14, 11]])

# %%
np.reshape(arr, (2,3), 'F')# Como lo hace fortrant, cogiendo por columnas
# Out:
# array([[13, 14,  2],
#        [18, 18, 11]])

# %%
np.reshape(arr, (2,3), 'A') # Segun la forma de guardado de mi laptop
# mejor forma para optimizar tiempo
# de normal C, que es como lo hace python
# Out:
# array([[13, 18, 18],
#        [ 2, 14, 11]])
